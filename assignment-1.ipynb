# %%
 #Task01
one = 1
two = 2
three = 3
four = 4
can = "can"
do = "do"
python = "python"
more = "more"
output = str(one) + " " + str(two) + " " + str(three) + " " + str(four) + " " + can + " " + do + " " + python + " " + more + " "
print (output)

# Task02
number1 = 15
number2 = 30
output = number1 * number2
print(output)

# Task03
numbers_x = [10, 20, 30, 40, 10]
numbers_y = [75, 65, 35, 75, 30]

#def numlist(num):
    if num[0] == num[-1]:
            return True
    else:
            return False
print(f"result is {numlist(numbers_y)}")

# Task04
numbers_z = [10, 20, 33, 46, 55]
def divlist(numdiv):
    print(f"Given list is {numdiv}")
    print("Divisible by 5")
    for numbers in numdiv:
        if numbers % 5 == 0: 
           print(numbers)
divlist(numbers_z)

# Task05
str_x = "Anjali is good developer. Anjali is a writer" 
find = "Anjali"
def countstr(strcount, findstr):
    count = strcount.count(findstr)
    print(f"{findstr} appeared {count} times")
countstr(str_x, find)

# Task06
rows = 5
for d in range(1, rows + 1):
    for e in range(1, d + 1):
        print(d, end=" ")
    print()


# Task07
rows=10
for f in range(1, rows + 1):
    for g in range(1,11):
        print(f * g, end=" ")
    print()

# Task08
import numpy as np
temp_k = [390.65, 107.52, 225.25, 275.98, 318.18, 88.45]
temp_c = np.array(temp_k) - 273.15
print(temp_c)

#task09
import pandas as pd
data = {
    'Student': [ 'Tommy', 'Fred', 'Gail', 'Dwayne', 'Randy', 'Ariel'],
    'Hair Color': ['Brown', 'Grey', 'Blonde', 'Brown', 'Black', 'Brown'],
    'Eye Color': ['Hazel', 'Green', 'Blue', 'Brown', 'Hazel', 'Blue'],
    'Weight in kilograms': [60, 80, 76, 60, 88, 85],
}
df = pd.DataFrame(data, index=['One', 'Two', 'Three', 'Four', 'Five', 'Six'])
print(df)
print(df[['Hair Color']])
print(df[['Eye Color']])
print(df[['Student', 'Weight in kilograms']])
print(df.iloc[1:4])
# Out:
#       Student  Weight in kilograms
# One     Tommy                   60
# Two      Fred                   80
# Three    Gail                   76
# Four   Dwayne                   60
# Five    Randy                   88
# Six     Ariel                   85
